# %%
from ultralytics import YOLO
import cv2
import json
import time
import numpy as np
import torch
import torchvision.transforms as transforms
from torchvision import models
from collections import defaultdict
from deep_sort_realtime.deepsort_tracker import DeepSort

model = YOLO("/home/mcw/Karthick/shopable-ad2.0/yolo_model/best_shop_mdl.pt")
model.to("cpu")

# Load classification model (ResNet) for suitcase classification
classification_model = models.resnet50(pretrained=False)
classification_model.fc = torch.nn.Linear(classification_model.fc.in_features, 4)  # 4 suitcase classes
classification_model.load_state_dict(torch.load("/home/mcw/Karthick/shopable-ad2.0/classification_model/suitcase_classify.pth", map_location=torch.device("cpu")))
classification_model.to("cpu")
classification_model.eval()

# Define product links and metadata
products = {
    "jacket": {
        "link": "https://www.ajio.com/brooks-brothers-stretch-tennis-zip-front-bomber-jacket/p/410309671001",
        "name": "Brooks Brothers Bomber Jacket",
        "price": "$129.99"
    },
    "suitcase1": {
        "link": "https://www.indiamart.com/proddetail/american-tourister-player-trolly-bag-2853815356891.html",
        "name": "Am  lly",
        "price": "$89.99"
    },
    "suitcase2": {
        "link": "https://www.americantourister.in/play4blue-blue-sb4061002",
        "name": "American Tourister Play4Blue",
        "price": "$95.99"
    },
    "suitcase3": {
        "link": "http://behance.net/gallery/84337561/American-Tourister-Bags?locale=es_ES",
        "name": "American Tourister Signature",
        "price": "$109.99"
    },
    "suitcase4": {
        "link": "https://www.flipkart.com/american-tourister-trafford-spinner-78cm-navy-check-in-suitcase-31-inch/p/itm0af067fc544c3",
        "name": "American Tourister Trafford Spinner",
        "price": "$119.99"
    }
}

def classify_object(cropped_img):
    """Classifies a cropped suitcase image and returns product info."""
    # Convert OpenCV BGR to RGB
    rgb_img = cv2.cvtColor(cropped_img, cv2.COLOR_BGR2RGB)
    
    # Create a PIL image
    pil_img = transforms.functional.to_pil_image(rgb_img)
    
    # Apply transformations
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    img_tensor = transform(pil_img).unsqueeze(0)
    
    with torch.no_grad():
        outputs = classification_model(img_tensor)
        _, predicted = torch.max(outputs, 1)
    
    product_key = f"suitcase{predicted.item() + 1}"
    return products.get(product_key, None)

def process_video(video_path, output_path, json_path):
    # Open video file
    cap = cv2.VideoCapture(video_path, cv2.CAP_FFMPEG)
    
    # Get video properties
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    
    print(f"Video properties: {width}x{height}, {fps} FPS, {total_frames} frames")
    
    # Define video writer
    fourcc = cv2.VideoWriter_fourcc(*'avc1')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height), isColor=True)
    
    # Initialize tracker with improved parameters
    tracker = DeepSort(
        max_age=1,              # Increased max age for tracks
        n_init=5,                # Decreased number of confirmations needed
        nms_max_overlap=0.5,     # Adjusted NMS overlap threshold
        max_cosine_distance=0.3, # Reduced cosine distance threshold for better matching
        nn_budget=100,           # Reduced neural network budget
        embedder="mobilenet",    # Using mobilenet embedder
        embedder_gpu=False       # Ensure CPU usage
    ) 
    
    # Store data for JSON output
    frame_data = {}
    object_data = defaultdict(dict)  # Track objects across frames
    object_first_seen = {}  # Track first frame an object was seen
    
    metadata = {
        "fps": fps,
        "width": width,
        "height": height,
        "total_frames": total_frames,
        "date_processed": time.strftime("%Y-%m-%d %H:%M:%S")
    }
    
    frame_id = 0
    processing_times = []
    
    # Track object class and product info
    object_details = {}
    
    # Process each frame
    while cap.isOpened():
        start_time = time.time()
        ret, frame = cap.read()
        
        if not ret:
            break
        
        # Run YOLOv8 object detection
        results = model(frame, conf=0.45, iou=0.4, device="cpu")
        
        # Prepare detections for tracker
        detections = []
        detection_classes = []
        detection_crops = []
        detection_confidences = []
        
        for result in results:
            for box, conf, cls in zip(result.boxes.xyxy, result.boxes.conf, result.boxes.cls):
                obj_class = int(cls.item())
                x1, y1, x2, y2 = map(int, box.tolist())
                conf_val = conf.item()
                
                # Add detection for tracking
                detections.append([x1, y1, x2, y2, conf_val])
                detection_classes.append(obj_class)
                detection_crops.append(frame[y1:y2, x1:x2].copy())
                detection_confidences.append(conf_val)
        
        frame_data[frame_id] = []
        
        # Update tracker
        if len(detections) > 0:
            # Convert detections to DeepSort format
            deep_sort_detections = []
            for det, cls, conf in zip(detections, detection_classes, detection_confidences):
                x1, y1, x2, y2, _ = det
                deep_sort_detections.append(
                    ((x1, y1, x2-x1, y2-y1), conf, cls)  # Convert to (x, y, w, h) format
                )
            
            # Track objects
            tracks = tracker.update_tracks(deep_sort_detections, frame=frame)
            
            for track in tracks:
                if not track.is_confirmed():
                    continue
                
                track_id = track.track_id
                ltrb = track.to_ltrb()
                x1, y1, x2, y2 = map(int, ltrb)
                
                # Match with original detection
                best_match_idx = None
                best_match_iou = 0
                for i, det in enumerate(detections):
                    det_x1, det_y1, det_x2, det_y2 = det[:4]
                    iou = calculate_iou((x1, y1, x2, y2), (det_x1, det_y1, det_x2, det_y2))
                    if iou > best_match_iou:
                        best_match_iou = iou
                        best_match_idx = i
                
                if best_match_idx is not None:
                    obj_class = detection_classes[best_match_idx]
                    cropped_img = detection_crops[best_match_idx]
                    
                    # Get product info based on class
                    product_info = None
                    if obj_class == 0:  # Jacket
                        product_info = products["jacket"]
                    elif obj_class == 1:  # Suitcase
                        product_info = classify_object(cropped_img)
                    
                    if product_info:
                        # Track first frame an object was seen
                        if track_id not in object_first_seen:
                            object_first_seen[track_id] = frame_id
                        
                        # Store frame data
                        frame_data[frame_id].append({
                            "id": track_id,
                            "bbox": [x1, y1, x2, y2],
                            "class": obj_class,
                            "link": product_info["link"],
                            "name": product_info["name"],
                            "price": product_info["price"]
                        })
                        
                        # Store persistent object details
                        object_details[track_id] = {
                            "class": obj_class,
                            "link": product_info["link"],
                            "name": product_info["name"],
                            "price": product_info["price"],
                            "first_frame": object_first_seen[track_id],
                            "last_frame": frame_id
                        }
                        
                        # Draw bounding boxes for visualization
                        color = get_color_for_id(track_id)
                        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
                        label = f"ID:{track_id} {product_info['name']}"
                        cv2.putText(frame, label, (x1, y1 - 10), 
                                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)
        
        # Write frame with visualization
        out.write(frame)
        
        # Calculate processing time
        end_time = time.time()
        processing_times.append(end_time - start_time)
        
        # Print progress every 10 frames
        if frame_id % 10 == 0:
            print(f"Processed frame {frame_id}/{total_frames}, time: {end_time - start_time:.3f}s")
        
        frame_id += 1
    
    # Calculate processing statistics
    avg_processing_time = np.mean(processing_times)
    effective_fps = 1.0 / avg_processing_time if avg_processing_time > 0 else 0
    
    # Prepare final JSON output
    output_data = {
        "metadata": metadata,
        "frames": frame_data,
        "objects": object_details,
        "stats": {
            "avg_processing_time": avg_processing_time,
            "effective_fps": effective_fps,
            "frames_processed": frame_id
        }
    }
    
    # Write output to JSON file
    with open(json_path, "w") as json_file:
        json.dump(output_data, json_file, indent=2)
    
    # Clean up
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    
    print(f"✅ Object detection and tracking complete. Output saved as '{output_path}'")
    print(f"✅ Tracking data saved as '{json_path}'")
    print(f"Processing stats: {effective_fps:.2f} FPS, {frame_id} frames processed")
    
    return output_data

def calculate_iou(box1, box2):
    """Calculate Intersection over Union (IoU) between two bounding boxes."""
    x1_1, y1_1, x2_1, y2_1 = box1
    x1_2, y1_2, x2_2, y2_2 = box2
    
    # Compute coordinates of the intersection box
    x1_inter = max(x1_1, x1_2)
    y1_inter = max(y1_1, y1_2)
    x2_inter = min(x2_1, x2_2)
    y2_inter = min(y2_1, y2_2)
    
    # Compute area of intersection
    inter_area = max(0, x2_inter - x1_inter) * max(0, y2_inter - y1_inter)
    
    # Compute area of both boxes
    box1_area = (x2_1 - x1_1) * (y2_1 - y1_1)
    box2_area = (x2_2 - x1_2) * (y2_2 - y1_2)
    
    # Compute union area
    union_area = box1_area + box2_area - inter_area
    
    # Compute IoU
    iou = inter_area / union_area if union_area > 0 else 0
    return iou

def get_color_for_id(track_id):
    try:
        # Try to convert to integer first
        if isinstance(track_id, str):
            # Use hash for string track IDs
            track_numeric = hash(track_id) 
        else:
            # Use the track_id directly if it's already numeric
            track_numeric = int(track_id)
    except (ValueError, TypeError):
        # Fallback to hash if conversion fails
        track_numeric = hash(str(track_id))
    
    # Ensure positive value
    track_numeric = abs(track_numeric)
    
    # Generate color components
    r = (track_numeric * 50) % 255
    g = (track_numeric * 100) % 255
    b = (track_numeric * 150) % 255
    
    return (r, g, b)

if __name__ == "__main__":
    input_video = "/home/mcw/Karthick/shopable-ad2.0/ad-video/ad.mp4"
    output_video = "processed_output.mp4"
    json_output = "/home/mcw/Karthick/shopable-ad2.0/data/tracked_id.json"
    
    process_video(input_video, output_video, json_output)
# Out:
# Video properties: 1920x1080, 25 FPS, 500 frames
#
# 0: 384x640 1 jacket, 1 suitcase, 34.0ms
# Speed: 1.3ms preprocess, 34.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 0/500, time: 0.144s
#
# 0: 384x640 1 jacket, 1 suitcase, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 33.0ms
# Speed: 2.1ms preprocess, 33.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 33.3ms
# Speed: 2.5ms preprocess, 33.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.7ms
# Speed: 2.9ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.3ms
# Speed: 3.0ms preprocess, 32.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.6ms
# Speed: 2.3ms preprocess, 32.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.7ms
# Speed: 1.4ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.6ms
# Speed: 3.1ms preprocess, 32.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 10/500, time: 0.131s
#
# 0: 384x640 1 jacket, 1 suitcase, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 33.8ms
# Speed: 1.8ms preprocess, 33.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.7ms
# Speed: 1.9ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.6ms
# Speed: 2.9ms preprocess, 32.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.2ms
# Speed: 3.4ms preprocess, 32.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 33.4ms
# Speed: 2.6ms preprocess, 33.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.6ms
# Speed: 4.2ms preprocess, 32.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 20/500, time: 0.127s
#
# 0: 384x640 1 jacket, 1 suitcase, 32.8ms
# Speed: 3.9ms preprocess, 32.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.4ms
# Speed: 2.6ms preprocess, 32.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 33.3ms
# Speed: 2.2ms preprocess, 33.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 33.2ms
# Speed: 1.5ms preprocess, 33.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 33.2ms
# Speed: 1.5ms preprocess, 33.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 33.8ms
# Speed: 1.9ms preprocess, 33.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 33.1ms
# Speed: 4.0ms preprocess, 33.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 30/500, time: 0.130s
#
# 0: 384x640 1 jacket, 1 suitcase, 33.5ms
# Speed: 2.3ms preprocess, 33.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 36.2ms
# Speed: 1.5ms preprocess, 36.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.7ms
# Speed: 2.3ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 1 suitcase, 32.4ms
# Speed: 3.9ms preprocess, 32.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 40/500, time: 0.128s
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.6ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.9ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.2ms
# Speed: 3.2ms preprocess, 32.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 2.6ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.4ms
# Speed: 1.5ms preprocess, 32.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 50/500, time: 0.080s
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.2ms
# Speed: 2.8ms preprocess, 32.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.3ms
# Speed: 2.7ms preprocess, 32.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 2.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 60/500, time: 0.081s
#
# 0: 384x640 1 jacket, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.6ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.2ms
# Speed: 3.9ms preprocess, 32.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 3.0ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.4ms
# Speed: 1.6ms preprocess, 32.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.2ms
# Speed: 3.0ms preprocess, 32.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 70/500, time: 0.082s
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.4ms
# Speed: 1.5ms preprocess, 32.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 2.1ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.8ms
# Speed: 1.8ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 3.8ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.2ms
# Speed: 2.5ms preprocess, 32.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 80/500, time: 0.078s
#
# 0: 384x640 2 jackets, 32.4ms
# Speed: 1.6ms preprocess, 32.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.7ms
# Speed: 2.7ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.4ms
# Speed: 1.5ms preprocess, 32.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.3ms
# Speed: 3.4ms preprocess, 32.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.9ms
# Speed: 1.6ms preprocess, 32.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.6ms
# Speed: 1.6ms preprocess, 32.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 90/500, time: 0.092s
#
# 0: 384x640 2 jackets, 33.6ms
# Speed: 2.5ms preprocess, 33.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.5ms
# Speed: 1.5ms preprocess, 32.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 34.4ms
# Speed: 1.5ms preprocess, 34.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.7ms
# Speed: 1.9ms preprocess, 32.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.5ms
# Speed: 1.5ms preprocess, 32.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 100/500, time: 0.094s
#
# 0: 384x640 2 jackets, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.6ms
# Speed: 2.7ms preprocess, 32.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 6.4ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.4ms
# Speed: 1.5ms preprocess, 32.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.4ms
# Speed: 1.6ms preprocess, 32.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.2ms
# Speed: 1.5ms preprocess, 32.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.0ms
# Speed: 3.1ms preprocess, 32.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 110/500, time: 0.080s
#
# 0: 384x640 1 jacket, 32.4ms
# Speed: 2.8ms preprocess, 32.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.2ms
# Speed: 3.5ms preprocess, 32.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.3ms
# Speed: 1.6ms preprocess, 32.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 2.8ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 2.5ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.8ms
# Speed: 1.6ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 120/500, time: 0.080s
#
# 0: 384x640 1 jacket, 33.6ms
# Speed: 1.6ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 3.1ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 2.9ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.4ms
# Speed: 2.4ms preprocess, 32.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.8ms
# Speed: 1.6ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.6ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.0ms
# Speed: 1.6ms preprocess, 33.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.2ms
# Speed: 1.5ms preprocess, 33.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 130/500, time: 0.082s
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.6ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 2.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.8ms
# Speed: 1.6ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.9ms
# Speed: 1.6ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.6ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.4ms
# Speed: 2.5ms preprocess, 32.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.9ms
# Speed: 2.3ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 3.5ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.4ms
# Speed: 3.2ms preprocess, 32.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 140/500, time: 0.082s
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 2.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.4ms
# Speed: 2.8ms preprocess, 32.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.8ms
# Speed: 2.5ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.6ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.8ms
# Speed: 1.6ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.2ms
# Speed: 1.5ms preprocess, 33.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 2.9ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 3.4ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.9ms
# Speed: 2.0ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 150/500, time: 0.081s
#
# 0: 384x640 1 jacket, 32.9ms
# Speed: 1.6ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.9ms
# Speed: 1.6ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.8ms
# Speed: 1.6ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.9ms
# Speed: 1.6ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.3ms
# Speed: 3.3ms preprocess, 32.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.0ms
# Speed: 1.6ms preprocess, 33.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 160/500, time: 0.079s
#
# 0: 384x640 1 jacket, 33.3ms
# Speed: 1.5ms preprocess, 33.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 2.5ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.3ms
# Speed: 2.9ms preprocess, 32.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 2.1ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 1.5ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.2ms
# Speed: 3.9ms preprocess, 32.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 170/500, time: 0.078s
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.4ms
# Speed: 2.5ms preprocess, 32.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 1.5ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 1.5ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 3.6ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 180/500, time: 0.079s
#
# 0: 384x640 1 jacket, 32.4ms
# Speed: 1.5ms preprocess, 32.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.4ms
# Speed: 1.8ms preprocess, 32.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 1.5ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.8ms
# Speed: 1.6ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.1ms
# Speed: 3.5ms preprocess, 32.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 4.3ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 190/500, time: 0.080s
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.8ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.4ms
# Speed: 3.7ms preprocess, 32.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.4ms
# Speed: 2.8ms preprocess, 32.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 200/500, time: 0.081s
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 2.8ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.6ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 2.6ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.6ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.5ms
# Speed: 1.5ms preprocess, 32.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.7ms
# Speed: 1.6ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.7ms
# Speed: 1.7ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 33.0ms
# Speed: 1.6ms preprocess, 33.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.6ms
# Speed: 1.7ms preprocess, 32.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 210/500, time: 0.094s
#
# 0: 384x640 2 jackets, 32.8ms
# Speed: 1.6ms preprocess, 32.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.1ms
# Speed: 3.6ms preprocess, 32.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.8ms
# Speed: 3.4ms preprocess, 32.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 33.0ms
# Speed: 1.9ms preprocess, 33.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.6ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.6ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.3ms
# Speed: 1.5ms preprocess, 32.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.2ms
# Speed: 3.9ms preprocess, 32.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 1.5ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.2ms
# Speed: 3.8ms preprocess, 32.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 220/500, time: 0.082s
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.3ms
# Speed: 3.0ms preprocess, 32.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.4ms
# Speed: 1.5ms preprocess, 32.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.6ms
# Speed: 2.0ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.2ms
# Speed: 2.7ms preprocess, 33.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 1.8ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 2.8ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 230/500, time: 0.081s
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.5ms
# Speed: 1.5ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.5ms
# Speed: 1.5ms preprocess, 32.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.6ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 34.1ms
# Speed: 1.5ms preprocess, 34.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.1ms
# Speed: 2.7ms preprocess, 33.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.6ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 240/500, time: 0.078s
#
# 0: 384x640 1 jacket, 32.6ms
# Speed: 1.5ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.3ms
# Speed: 1.6ms preprocess, 32.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.4ms
# Speed: 1.5ms preprocess, 32.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.2ms
# Speed: 3.4ms preprocess, 33.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.2ms
# Speed: 1.5ms preprocess, 33.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.6ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 250/500, time: 0.080s
#
# 0: 384x640 1 jacket, 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 34.2ms
# Speed: 1.5ms preprocess, 34.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.8ms
# Speed: 2.6ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.4ms
# Speed: 1.5ms preprocess, 33.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.7ms
# Speed: 1.6ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 32.8ms
# Speed: 1.6ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 260/500, time: 0.094s
#
# 0: 384x640 2 jackets, 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 33.3ms
# Speed: 1.5ms preprocess, 33.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 33.4ms
# Speed: 1.5ms preprocess, 33.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.8ms
# Speed: 1.6ms preprocess, 32.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 33.2ms
# Speed: 1.5ms preprocess, 33.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 270/500, time: 0.093s
#
# 0: 384x640 2 jackets, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 33.5ms
# Speed: 1.6ms preprocess, 33.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 32.5ms
# Speed: 2.2ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 32.6ms
# Speed: 2.6ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 280/500, time: 0.204s
#
# 0: 384x640 1 suitcase, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.0ms
# Speed: 3.5ms preprocess, 33.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.9ms
# Speed: 2.3ms preprocess, 33.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 32.6ms
# Speed: 2.8ms preprocess, 32.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.2ms
# Speed: 1.6ms preprocess, 33.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 290/500, time: 0.119s
#
# 0: 384x640 1 suitcase, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.0ms
# Speed: 1.6ms preprocess, 33.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 32.8ms
# Speed: 1.6ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 32.8ms
# Speed: 1.6ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.0ms
# Speed: 1.4ms preprocess, 33.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.3ms
# Speed: 1.5ms preprocess, 33.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 300/500, time: 0.117s
#
# 0: 384x640 1 suitcase, 33.3ms
# Speed: 1.5ms preprocess, 33.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.5ms
# Speed: 2.4ms preprocess, 33.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.4ms
# Speed: 1.5ms preprocess, 33.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.8ms
# Speed: 1.6ms preprocess, 32.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.2ms
# Speed: 1.7ms preprocess, 33.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.2ms
# Speed: 3.1ms preprocess, 33.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.9ms
# Speed: 1.9ms preprocess, 32.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 310/500, time: 0.054s
#
# 0: 384x640 (no detections), 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.7ms
# Speed: 1.6ms preprocess, 32.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.9ms
# Speed: 1.6ms preprocess, 32.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.7ms
# Speed: 1.6ms preprocess, 33.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.3ms
# Speed: 1.6ms preprocess, 34.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.2ms
# Speed: 1.6ms preprocess, 34.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 320/500, time: 0.059s
#
# 0: 384x640 (no detections), 34.4ms
# Speed: 1.5ms preprocess, 34.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.2ms
# Speed: 1.5ms preprocess, 34.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.3ms
# Speed: 1.5ms preprocess, 34.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.1ms
# Speed: 1.6ms preprocess, 34.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.2ms
# Speed: 1.5ms preprocess, 34.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.6ms
# Speed: 2.9ms preprocess, 33.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 34.1ms
# Speed: 1.5ms preprocess, 34.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 330/500, time: 0.076s
#
# 0: 384x640 2 jackets, 34.1ms
# Speed: 1.4ms preprocess, 34.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 jackets, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.5ms
# Speed: 1.4ms preprocess, 33.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 340/500, time: 0.082s
#
# 0: 384x640 1 jacket, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.8ms
# Speed: 1.6ms preprocess, 33.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.6ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 350/500, time: 0.079s
#
# 0: 384x640 1 jacket, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.6ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 360/500, time: 0.078s
#
# 0: 384x640 1 jacket, 38.6ms
# Speed: 1.6ms preprocess, 38.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 34.0ms
# Speed: 1.4ms preprocess, 34.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 34.1ms
# ...
# Processed frame 380/500, time: 0.085s
#
# 0: 384x640 1 jacket, 34.1ms
# Speed: 1.5ms preprocess, 34.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 34.1ms
# Speed: 1.5ms preprocess, 34.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 34.1ms
# Speed: 1.5ms preprocess, 34.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 34.2ms
# Speed: 1.5ms preprocess, 34.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 34.1ms
# Speed: 1.5ms preprocess, 34.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 34.1ms
# Speed: 1.5ms preprocess, 34.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 34.1ms
# Speed: 1.5ms preprocess, 34.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 34.0ms
# Speed: 1.6ms preprocess, 34.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 34.3ms
# Speed: 1.6ms preprocess, 34.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 390/500, time: 0.076s
#
# 0: 384x640 1 jacket, 34.1ms
# Speed: 1.5ms preprocess, 34.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 34.3ms
# Speed: 1.5ms preprocess, 34.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.5ms
# Speed: 1.6ms preprocess, 33.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.6ms
# Speed: 1.6ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 400/500, time: 0.076s
#
# 0: 384x640 1 jacket, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.9ms
# Speed: 1.6ms preprocess, 33.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 410/500, time: 0.075s
#
# 0: 384x640 1 jacket, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.5ms
# Speed: 1.6ms preprocess, 33.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.4ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 420/500, time: 0.075s
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 jacket, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.6ms
# Speed: 1.6ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 430/500, time: 0.119s
#
# 0: 384x640 1 suitcase, 33.4ms
# Speed: 1.5ms preprocess, 33.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.6ms
# Speed: 1.6ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.7ms
# Speed: 1.4ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.4ms
# Speed: 1.5ms preprocess, 33.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 440/500, time: 0.119s
#
# 0: 384x640 1 suitcase, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.6ms
# Speed: 1.6ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 34.1ms
# Speed: 1.4ms preprocess, 34.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 450/500, time: 0.114s
#
# 0: 384x640 4 suitcases, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 34.6ms
# Speed: 1.5ms preprocess, 34.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 34.3ms
# Speed: 1.5ms preprocess, 34.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 33.8ms
# Speed: 1.4ms preprocess, 33.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 33.4ms
# Speed: 3.7ms preprocess, 33.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 460/500, time: 0.276s
#
# 0: 384x640 4 suitcases, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 33.6ms
# Speed: 1.6ms preprocess, 33.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 34.1ms
# Speed: 1.6ms preprocess, 34.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 33.9ms
# Speed: 1.4ms preprocess, 33.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 35.3ms
# Speed: 1.5ms preprocess, 35.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 34.1ms
# Speed: 1.6ms preprocess, 34.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 470/500, time: 0.279s
#
# 0: 384x640 4 suitcases, 34.1ms
# Speed: 1.5ms preprocess, 34.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 34.0ms
# Speed: 1.4ms preprocess, 34.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 34.0ms
# Speed: 1.7ms preprocess, 34.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 33.9ms
# Speed: 1.4ms preprocess, 33.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 34.0ms
# Speed: 1.4ms preprocess, 34.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 480/500, time: 0.278s
#
# 0: 384x640 4 suitcases, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 33.8ms
# Speed: 1.4ms preprocess, 33.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 suitcases, 33.8ms
# Speed: 1.6ms preprocess, 33.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.0ms
# Speed: 1.4ms preprocess, 34.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.2ms
# Speed: 1.4ms preprocess, 34.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed frame 490/500, time: 0.045s
#
# 0: 384x640 (no detections), 34.0ms
# Speed: 1.4ms preprocess, 34.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.3ms
# Speed: 1.4ms preprocess, 34.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.9ms
# Speed: 1.4ms preprocess, 33.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.0ms
# Speed: 1.4ms preprocess, 34.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.2ms
# Speed: 1.4ms preprocess, 34.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.9ms
# Speed: 1.4ms preprocess, 33.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.1ms
# Speed: 1.4ms preprocess, 34.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.1ms
# Speed: 1.4ms preprocess, 34.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.3ms
# Speed: 1.4ms preprocess, 34.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Object detection and tracking complete. Output saved as 'processed_output.mp4'
# ✅ Tracking data saved as '/home/mcw/Karthick/shopable-ad2.0/data/tracked_id.json'
# Processing stats: 10.02 FPS, 500 frames processed

# %%
from ultralytics import YOLO

# Load your trained YOLOv8 model
model = YOLO("/home/mcw/Karthick/shopable-ad2.0/yolo_model/best_shop_mdl.pt")  # Change to your model path

# Print model architecture
print(model)

# Print class names and number of classes
print("\nModel Classes:")

for class_id, class_name in model.names.items():
    print(f"Class ID: {class_id}, Class Name: {class_name}")

# Print additional model details
print("\nModel Summary:")
model.info()
# Out:
# YOLO(
#   (model): SegmentationModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (4): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (5): Conv(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (6): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (7): Conv(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (8): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (9): SPPF(
#         (cv1): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (10): Upsample(scale_factor=2.0, mode='nearest')
#       (11): Concat()
#       (12): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (13): Upsample(scale_factor=2.0, mode='nearest')
#       (14): Concat()
#       (15): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (16): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (17): Concat()
#       (18): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (19): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (20): Concat()
#       (21): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (22): Segment(
#         (cv2): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (cv3): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 2, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 2, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 2, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (dfl): DFL(
#           (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (proto): Proto(
#           (cv1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (upsample): ConvTranspose2d(64, 64, kernel_size=(2, 2), stride=(2, 2))
#           (cv2): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (cv4): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#   )
# )
#
# Model Classes:
# Class ID: 0, Class Name: jacket
# Class ID: 1, Class Name: suitcase
#
# Model Summary:
# YOLOv8n-seg summary: 151 layers, 3,264,006 parameters, 0 gradients, 12.1 GFLOPs
# (151, 3264006, 0, 12.110387199999998)
